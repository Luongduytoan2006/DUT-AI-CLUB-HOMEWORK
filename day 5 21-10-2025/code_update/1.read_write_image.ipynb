# %% [markdown]
# ## Read and show an image

# %% [markdown]
# #### using matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# read a grayscale image and plot it
img = mpimg.imread('nature.jpg', 0)
print(img)
print("Shape:", img.shape)  # (1200, 1200)
print("Pixel ở vị trí [0, 0]:", img[0, 0])  # Ví dụ: 145
print("Pixel ở vị trí [100, 200]:", img[100, 200])  # Ví dụ: 78
imgplot = plt.imshow(img, cmap='gray')
print(imgplot)
plt.show()
# Out:
# [[ 53  79 111 ...  85  80  74]
#  [108 121 130 ...  90  90  88]
#  [135 141 142 ...  73  74  74]
#  ...
#  [ 13  15  15 ...  83 102  91]
#  [ 17  19  21 ...  76 103 109]
#  [ 19  22  25 ...  50  76  89]]
# Shape: (500, 1200)
# Pixel ở vị trí [0, 0]: 53
# Pixel ở vị trí [100, 200]: 84
# AxesImage(shape=(500, 1200))

# %% [markdown]
# #### using matplotlib and opencv

# %%
import matplotlib.pyplot as plt
import cv2

# read a grayscale image and plot it
img = cv2.imread('nature.jpg', 0)
print(img)
print("Shape:", img.shape)  # (1200, 1200)
print("Pixel ở vị trí [0, 0]:", img[0, 0])  # Ví dụ: 145
print("Pixel ở vị trí [100, 200]:", img[100, 200])  # Ví dụ: 78
imgplot = plt.imshow(img, cmap='gray')
plt.show()
# Out:
# [[ 53  79 111 ...  85  80  74]
#  [108 121 130 ...  90  90  88]
#  [135 141 142 ...  73  74  74]
#  ...
#  [ 13  15  15 ...  83 102  91]
#  [ 17  19  21 ...  76 103 109]
#  [ 19  22  25 ...  50  76  89]]
# Shape: (500, 1200)
# Pixel ở vị trí [0, 0]: 53
# Pixel ở vị trí [100, 200]: 84

# %% [markdown]
# ## Read and write an image

# %%
import cv2

# read a grayscale image
data = cv2.imread('nature.jpg', 0)

# save the image
cv2.imwrite('1.nature_1.jpg', data)
# Out:
# True

# %% [markdown]
# ## Using list as intermediate data

# %%
import cv2
import numpy as np

# read a grayscale image (nd.array)
data = cv2.imread('nature.jpg', 0)

# convert from np.array to 2d list
data = img.tolist()
height = len(data)
width  = len(data[0])
print(f'Height: {height} and width:{width}')

# conver from 2d list to np.array
data = np.array(data)

# save the image
cv2.imwrite('1.nature_2.jpg', data)
# Out:
# Height: 500 and width:1200
# True

# %%
import cv2
import numpy as np

# read a grayscale image (nd.array)
data = cv2.imread('nature.jpg', 0).tolist()

height = len(data)
width  = len(data[0])
print(f'Height: {height} and width:{width}')

# save the image
cv2.imwrite('1.nature_2.jpg', np.array(data))
# Out:
# Height: 500 and width:1200
# True

# %%
import numpy as np

def computeMean(X):
  return np.mean(X) 

X = [2, 0, 2, 2, 7, 4, -2, 5, -1, -1]
print("Mean:", computeMean(X))
# Out:
# Mean: 1.8

# %%
def computeMedian(X):
  n = len(X)
  X = np.sort(X)
  
  if (n % 2 == 0):
    return (X[n // 2 - 1] + X[n // 2]) / 2
  else:
    return X[n // 2]

X = [1, 5, 4, 4, 9, 13]
print("Median:", computeMedian(X))
# Out:
# Median: 4.5

# %%
def compute_std(X):
  mean = computeMean(X)
  variance = 0
  
  # Tính tổng bình phương độ lệch
  for x in X:
    variance += (x - mean) ** 2
  
  variance = variance / len(X)
  return np.sqrt(variance)

X = [171, 176, 155, 167, 169, 182]
print("Standard Deviation:", np.round(compute_std(X), 2))
# Out:
# Standard Deviation: 8.33

# %%
def computeCorrelationCofficient(X, Y):
  
  mean_x = computeMean(X)
  mean_y = computeMean(Y)
  
  numerator = np.sum((X - mean_x) * (Y - mean_y))
  
  std_x = np.sum((X - mean_x) ** 2)
  std_y = np.sum((Y - mean_y) ** 2)
  denominator = np.sqrt(std_x * std_y)
  
  return np.round(numerator / denominator, 2)

X = np.asarray([-2, -5, -11, 6, 4, 15, 9])
Y = np.asarray([4, 25, 121, 36, 16, 225, 81])
print("Correlation:", computeCorrelationCofficient(X, Y))
# Out:
# Correlation: 0.42
